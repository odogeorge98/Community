# %%
# !pip -q install -U pip
# !pip -q install exllamav2 huggingface_hub

# !git clone https://github.com/Mozer/YuE-extend
# %cd YuE-extend

# !pip -q install -r requirements.txt
# !git clone https://huggingface.co/m-a-p/xcodec_mini_infer

# !pip -q install --upgrade protobuf
# !pip -q uninstall -y flash-attn || true

# !mkdir -p workspace/models workspace/outputs
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 39.1 MB/s eta 0:00:00
# Cloning into 'YuE-extend'...
# remote: Enumerating objects: 853, done.
# remote: Counting objects: 100% (170/170), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 853 (delta 153), reused 132 (delta 132), pack-reused 683 (from 1)
# Receiving objects: 100% (853/853), 20.49 MiB | 21.28 MiB/s, done.
# Resolving deltas: 100% (442/442), done.
# /content/YuE-extend
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> No available output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build wheel ... error
# ERROR: Failed to build 'flash-attn' when getting requirements to build wheel
# Cloning into 'xcodec_mini_infer'...
# remote: Enumerating objects: 203, done.
# ...
